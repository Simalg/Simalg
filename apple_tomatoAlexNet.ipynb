# %% [markdown]
# <a href="https://colab.research.google.com/github/Simalg/Simalg/blob/main/apple_tomatoAlexNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import load_img, img_to_array

from sklearn.metrics import confusion_matrix

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_path = "/content/drive/MyDrive/apple-tomato/train"

# %%
val_path = "/content/drive/MyDrive/apple-tomato/test"

# %%
data_gen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = data_gen.flow_from_directory(
  train_path,
  target_size=(224, 224),
  batch_size=32,
  class_mode='binary',
  shuffle=True)
# Out:
# Found 294 images belonging to 2 classes.

# %%
val_generator = data_gen.flow_from_directory(
  val_path,
  target_size=(224, 224),
  batch_size=16,
  class_mode='binary',
  shuffle=False)
# Out:
# Found 97 images belonging to 2 classes.

# %%
input_shape, num_classes = (224, 224, 3), 1

# %%
input = Input(shape=input_shape)

x = Conv2D(96, (11, 11), strides=(4, 4), activation='relu')(input)
x = MaxPooling2D((3, 3), strides=(2, 2))(x)
x = Conv2D(256, (5, 5), activation='relu')(x)
x = MaxPooling2D((3, 3), strides=(2, 2))(x)
x = Conv2D(384, (3, 3), activation='relu')(x)
x = Conv2D(384, (3, 3), activation='relu')(x)
x = Conv2D(256, (3, 3), activation='relu')(x)
x = MaxPooling2D((3, 3), strides=(2, 2))(x)
x = Flatten()(x)
x = Dense(4096, activation='relu')(x)
x = Dense(4096, activation='relu')(x)

output_layer = Dense(num_classes, activation='sigmoid')(x)
model = Model(inputs=input, outputs=output_layer)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 54, 54, 96)        34944
#
#  max_pooling2d (MaxPooling2  (None, 26, 26, 96)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 22, 22, 256)       614656
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 256)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 384)         885120
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 384)         1327488
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 256)         884992
#
#  max_pooling2d_2 (MaxPoolin  (None, 1, 1, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 21585281 (82.34 MB)
# Trainable params: 21585281 (82.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

# %%
model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
fit_history = model.fit_generator(
    train_generator,
    epochs=100,
    validation_data=val_generator,
)
# Out:
# <ipython-input-18-6a2829a8601d>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   fit_history = model.fit_generator(
# Epoch 1/100
# 10/10 [==============================] - 59s 5s/step - loss: 0.6925 - accuracy: 0.5510 - precision: 0.4857 - recall: 0.2615 - val_loss: 0.6920 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6913 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6908 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.6905 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6905 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6899 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6895 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.6890 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6888 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.6884 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6881 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/100
# 10/10 [==============================] - 2s 170ms/step - loss: 0.6878 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6873 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.6869 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6868 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/100
# 10/10 [==============================] - 1s 147ms/step - loss: 0.6863 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6862 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.6858 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6857 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.6854 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6854 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.6849 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6850 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.6848 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6844 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6840 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6839 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.6834 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6833 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.6829 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6830 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6824 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6823 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.6816 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6818 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/100
# 10/10 [==============================] - 2s 193ms/step - loss: 0.6811 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6812 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/100
# 10/10 [==============================] - 1s 137ms/step - loss: 0.6804 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6803 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6794 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6801 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.6790 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6787 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6785 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6778 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6789 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6769 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.6754 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6755 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.6738 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6774 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6751 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6735 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6710 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6719 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.6701 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6702 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.6690 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6684 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/100
# 10/10 [==============================] - 2s 172ms/step - loss: 0.6699 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6669 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.6624 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6701 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6631 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6628 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.6600 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6606 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6529 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6578 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.6528 - accuracy: 0.5578 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.6604 - val_accuracy: 0.5567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6711 - accuracy: 0.5952 - precision: 0.6078 - recall: 0.2385 - val_loss: 0.6556 - val_accuracy: 0.5670 - val_precision: 1.0000 - val_recall: 0.0233
# Epoch 38/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6545 - accuracy: 0.6020 - precision: 0.8421 - recall: 0.1231 - val_loss: 0.6519 - val_accuracy: 0.6392 - val_precision: 1.0000 - val_recall: 0.1860
# Epoch 39/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.6762 - accuracy: 0.5510 - precision: 0.4938 - recall: 0.6077 - val_loss: 0.6784 - val_accuracy: 0.6598 - val_precision: 0.6316 - val_recall: 0.5581
# Epoch 40/100
# 10/10 [==============================] - 1s 136ms/step - loss: 0.6544 - accuracy: 0.6224 - precision: 0.9524 - recall: 0.1538 - val_loss: 0.6652 - val_accuracy: 0.6804 - val_precision: 0.6875 - val_recall: 0.5116
# Epoch 41/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.6431 - accuracy: 0.6429 - precision: 0.7778 - recall: 0.2692 - val_loss: 0.6455 - val_accuracy: 0.6082 - val_precision: 0.7273 - val_recall: 0.1860
# Epoch 42/100
# 10/10 [==============================] - 1s 135ms/step - loss: 0.6444 - accuracy: 0.6156 - precision: 0.7576 - recall: 0.1923 - val_loss: 0.6583 - val_accuracy: 0.6804 - val_precision: 0.6579 - val_recall: 0.5814
# Epoch 43/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.6396 - accuracy: 0.6497 - precision: 0.6849 - recall: 0.3846 - val_loss: 0.6543 - val_accuracy: 0.5979 - val_precision: 0.7500 - val_recall: 0.1395
# Epoch 44/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.6369 - accuracy: 0.6429 - precision: 0.7660 - recall: 0.2769 - val_loss: 0.6760 - val_accuracy: 0.5670 - val_precision: 0.5070 - val_recall: 0.8372
# Epoch 45/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.6284 - accuracy: 0.6803 - precision: 0.6698 - recall: 0.5462 - val_loss: 0.6590 - val_accuracy: 0.5876 - val_precision: 0.6667 - val_recall: 0.1395
# Epoch 46/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.6355 - accuracy: 0.6463 - precision: 0.6477 - recall: 0.4385 - val_loss: 0.6330 - val_accuracy: 0.6598 - val_precision: 0.6786 - val_recall: 0.4419
# Epoch 47/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.6257 - accuracy: 0.6667 - precision: 0.7000 - recall: 0.4308 - val_loss: 0.6449 - val_accuracy: 0.6598 - val_precision: 0.6000 - val_recall: 0.6977
# Epoch 48/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.6434 - accuracy: 0.6395 - precision: 0.6463 - recall: 0.4077 - val_loss: 0.6293 - val_accuracy: 0.6598 - val_precision: 0.6667 - val_recall: 0.4651
# Epoch 49/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6427 - accuracy: 0.6259 - precision: 0.5926 - recall: 0.4923 - val_loss: 0.6334 - val_accuracy: 0.6392 - val_precision: 0.6818 - val_recall: 0.3488
# Epoch 50/100
# 10/10 [==============================] - 2s 249ms/step - loss: 0.6250 - accuracy: 0.6497 - precision: 0.6452 - recall: 0.4615 - val_loss: 0.6295 - val_accuracy: 0.6598 - val_precision: 0.6667 - val_recall: 0.4651
# Epoch 51/100
# 10/10 [==============================] - 2s 163ms/step - loss: 0.6225 - accuracy: 0.6429 - precision: 0.6068 - recall: 0.5462 - val_loss: 0.6505 - val_accuracy: 0.6186 - val_precision: 0.7143 - val_recall: 0.2326
# Epoch 52/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.6161 - accuracy: 0.6973 - precision: 0.7158 - recall: 0.5231 - val_loss: 0.6279 - val_accuracy: 0.6804 - val_precision: 0.6667 - val_recall: 0.5581
# Epoch 53/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.6214 - accuracy: 0.6293 - precision: 0.5882 - recall: 0.5385 - val_loss: 0.6251 - val_accuracy: 0.6598 - val_precision: 0.6667 - val_recall: 0.4651
# Epoch 54/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.6235 - accuracy: 0.6531 - precision: 0.6321 - recall: 0.5154 - val_loss: 0.6645 - val_accuracy: 0.5876 - val_precision: 0.5238 - val_recall: 0.7674
# Epoch 55/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6029 - accuracy: 0.6905 - precision: 0.6931 - recall: 0.5385 - val_loss: 0.6668 - val_accuracy: 0.5773 - val_precision: 0.5147 - val_recall: 0.8140
# Epoch 56/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.6231 - accuracy: 0.6803 - precision: 0.6636 - recall: 0.5615 - val_loss: 0.6356 - val_accuracy: 0.6392 - val_precision: 0.7222 - val_recall: 0.3023
# Epoch 57/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.6432 - accuracy: 0.6122 - precision: 0.5714 - recall: 0.4923 - val_loss: 0.6416 - val_accuracy: 0.6186 - val_precision: 0.5577 - val_recall: 0.6744
# Epoch 58/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.6036 - accuracy: 0.6667 - precision: 0.6455 - recall: 0.5462 - val_loss: 0.6155 - val_accuracy: 0.6907 - val_precision: 0.6857 - val_recall: 0.5581
# Epoch 59/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.6396 - accuracy: 0.6122 - precision: 0.5714 - recall: 0.4923 - val_loss: 0.6211 - val_accuracy: 0.6598 - val_precision: 0.6136 - val_recall: 0.6279
# Epoch 60/100
# 10/10 [==============================] - 3s 280ms/step - loss: 0.6365 - accuracy: 0.6429 - precision: 0.6126 - recall: 0.5231 - val_loss: 0.6123 - val_accuracy: 0.6907 - val_precision: 0.7241 - val_recall: 0.4884
# Epoch 61/100
# 10/10 [==============================] - 2s 151ms/step - loss: 0.5957 - accuracy: 0.6803 - precision: 0.7000 - recall: 0.4846 - val_loss: 0.6747 - val_accuracy: 0.5567 - val_precision: 0.5000 - val_recall: 0.8605
# Epoch 62/100
# 10/10 [==============================] - 2s 168ms/step - loss: 0.6184 - accuracy: 0.6837 - precision: 0.6434 - recall: 0.6385 - val_loss: 0.6234 - val_accuracy: 0.6289 - val_precision: 0.6667 - val_recall: 0.3256
# Epoch 63/100
# 10/10 [==============================] - 2s 173ms/step - loss: 0.6504 - accuracy: 0.6667 - precision: 0.6818 - recall: 0.4615 - val_loss: 0.6506 - val_accuracy: 0.6082 - val_precision: 0.6923 - val_recall: 0.2093
# Epoch 64/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.6048 - accuracy: 0.6667 - precision: 0.6667 - recall: 0.4923 - val_loss: 0.6151 - val_accuracy: 0.6804 - val_precision: 0.7143 - val_recall: 0.4651
# Epoch 65/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.5850 - accuracy: 0.6837 - precision: 0.6667 - recall: 0.5692 - val_loss: 0.6107 - val_accuracy: 0.6907 - val_precision: 0.6585 - val_recall: 0.6279
# Epoch 66/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.6141 - accuracy: 0.6667 - precision: 0.6250 - recall: 0.6154 - val_loss: 0.6058 - val_accuracy: 0.7010 - val_precision: 0.7333 - val_recall: 0.5116
# Epoch 67/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.6105 - accuracy: 0.6701 - precision: 0.6854 - recall: 0.4692 - val_loss: 0.6092 - val_accuracy: 0.7010 - val_precision: 0.7059 - val_recall: 0.5581
# Epoch 68/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.5946 - accuracy: 0.7143 - precision: 0.7447 - recall: 0.5385 - val_loss: 0.6912 - val_accuracy: 0.5258 - val_precision: 0.4805 - val_recall: 0.8605
# Epoch 69/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.5860 - accuracy: 0.6871 - precision: 0.6508 - recall: 0.6308 - val_loss: 0.5978 - val_accuracy: 0.7010 - val_precision: 0.7333 - val_recall: 0.5116
# Epoch 70/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.5964 - accuracy: 0.6871 - precision: 0.6696 - recall: 0.5769 - val_loss: 0.6053 - val_accuracy: 0.6804 - val_precision: 0.7143 - val_recall: 0.4651
# Epoch 71/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.6433 - accuracy: 0.6224 - precision: 0.5922 - recall: 0.4692 - val_loss: 0.7401 - val_accuracy: 0.4845 - val_precision: 0.4598 - val_recall: 0.9302
# Epoch 72/100
# 10/10 [==============================] - 1s 131ms/step - loss: 0.5992 - accuracy: 0.6973 - precision: 0.6475 - recall: 0.6923 - val_loss: 0.5966 - val_accuracy: 0.7010 - val_precision: 0.7333 - val_recall: 0.5116
# Epoch 73/100
# 10/10 [==============================] - 1s 130ms/step - loss: 0.5695 - accuracy: 0.6735 - precision: 0.6545 - recall: 0.5538 - val_loss: 0.6367 - val_accuracy: 0.6289 - val_precision: 0.5556 - val_recall: 0.8140
# Epoch 74/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.6256 - accuracy: 0.6599 - precision: 0.6415 - recall: 0.5231 - val_loss: 0.6488 - val_accuracy: 0.6082 - val_precision: 0.5385 - val_recall: 0.8140
# Epoch 75/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.5921 - accuracy: 0.6735 - precision: 0.6181 - recall: 0.6846 - val_loss: 0.6447 - val_accuracy: 0.6495 - val_precision: 0.7647 - val_recall: 0.3023
# Epoch 76/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.6754 - accuracy: 0.6190 - precision: 0.5900 - recall: 0.4538 - val_loss: 0.6478 - val_accuracy: 0.6186 - val_precision: 0.8000 - val_recall: 0.1860
# Epoch 77/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.5912 - accuracy: 0.6803 - precision: 0.7143 - recall: 0.4615 - val_loss: 0.5885 - val_accuracy: 0.7010 - val_precision: 0.7059 - val_recall: 0.5581
# Epoch 78/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6024 - accuracy: 0.6667 - precision: 0.6231 - recall: 0.6231 - val_loss: 0.6057 - val_accuracy: 0.7423 - val_precision: 0.6731 - val_recall: 0.8140
# Epoch 79/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5753 - accuracy: 0.6939 - precision: 0.6786 - recall: 0.5846 - val_loss: 0.5783 - val_accuracy: 0.7010 - val_precision: 0.7188 - val_recall: 0.5349
# Epoch 80/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6097 - accuracy: 0.6701 - precision: 0.6460 - recall: 0.5615 - val_loss: 0.6120 - val_accuracy: 0.7010 - val_precision: 0.6250 - val_recall: 0.8140
# Epoch 81/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.5787 - accuracy: 0.6837 - precision: 0.6434 - recall: 0.6385 - val_loss: 0.6049 - val_accuracy: 0.7216 - val_precision: 0.6481 - val_recall: 0.8140
# Epoch 82/100
# 10/10 [==============================] - 2s 150ms/step - loss: 0.5612 - accuracy: 0.7007 - precision: 0.6750 - recall: 0.6231 - val_loss: 0.5910 - val_accuracy: 0.7423 - val_precision: 0.6731 - val_recall: 0.8140
# Epoch 83/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.6257 - accuracy: 0.6667 - precision: 0.6481 - recall: 0.5385 - val_loss: 0.5862 - val_accuracy: 0.7010 - val_precision: 0.7333 - val_recall: 0.5116
# Epoch 84/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.5896 - accuracy: 0.6599 - precision: 0.6210 - recall: 0.5923 - val_loss: 0.6242 - val_accuracy: 0.6495 - val_precision: 0.5738 - val_recall: 0.8140
# Epoch 85/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.5772 - accuracy: 0.6871 - precision: 0.6397 - recall: 0.6692 - val_loss: 0.6191 - val_accuracy: 0.6598 - val_precision: 0.7778 - val_recall: 0.3256
# Epoch 86/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6146 - accuracy: 0.6633 - precision: 0.6281 - recall: 0.5846 - val_loss: 0.6045 - val_accuracy: 0.7320 - val_precision: 0.6604 - val_recall: 0.8140
# Epoch 87/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.5488 - accuracy: 0.7313 - precision: 0.7339 - recall: 0.6154 - val_loss: 0.6045 - val_accuracy: 0.6495 - val_precision: 0.5714 - val_recall: 0.8372
# Epoch 88/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.6074 - accuracy: 0.6735 - precision: 0.6308 - recall: 0.6308 - val_loss: 0.5800 - val_accuracy: 0.7216 - val_precision: 0.6818 - val_recall: 0.6977
# Epoch 89/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.5682 - accuracy: 0.6837 - precision: 0.6504 - recall: 0.6154 - val_loss: 0.5741 - val_accuracy: 0.7113 - val_precision: 0.7419 - val_recall: 0.5349
# Epoch 90/100
# 10/10 [==============================] - 1s 132ms/step - loss: 0.5397 - accuracy: 0.7313 - precision: 0.7143 - recall: 0.6538 - val_loss: 0.6021 - val_accuracy: 0.7010 - val_precision: 0.6250 - val_recall: 0.8140
# Epoch 91/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6018 - accuracy: 0.6735 - precision: 0.6232 - recall: 0.6615 - val_loss: 0.5945 - val_accuracy: 0.6701 - val_precision: 0.7200 - val_recall: 0.4186
# Epoch 92/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.5684 - accuracy: 0.6905 - precision: 0.6560 - recall: 0.6308 - val_loss: 0.6887 - val_accuracy: 0.6289 - val_precision: 0.8182 - val_recall: 0.2093
# Epoch 93/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.5688 - accuracy: 0.7007 - precision: 0.6641 - recall: 0.6538 - val_loss: 0.7882 - val_accuracy: 0.6082 - val_precision: 0.7778 - val_recall: 0.1628
# Epoch 94/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.6033 - accuracy: 0.6837 - precision: 0.6762 - recall: 0.5462 - val_loss: 0.5895 - val_accuracy: 0.7216 - val_precision: 0.6600 - val_recall: 0.7674
# Epoch 95/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.5712 - accuracy: 0.6939 - precision: 0.6639 - recall: 0.6231 - val_loss: 0.5781 - val_accuracy: 0.7216 - val_precision: 0.6739 - val_recall: 0.7209
# Epoch 96/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.6137 - accuracy: 0.6701 - precision: 0.6222 - recall: 0.6462 - val_loss: 0.5753 - val_accuracy: 0.7216 - val_precision: 0.7000 - val_recall: 0.6512
# Epoch 97/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5494 - accuracy: 0.7041 - precision: 0.6838 - recall: 0.6154 - val_loss: 0.5596 - val_accuracy: 0.7010 - val_precision: 0.6944 - val_recall: 0.5814
# Epoch 98/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5919 - accuracy: 0.6973 - precision: 0.6916 - recall: 0.5692 - val_loss: 0.5864 - val_accuracy: 0.7216 - val_precision: 0.6481 - val_recall: 0.8140
# Epoch 99/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.5507 - accuracy: 0.7245 - precision: 0.7025 - recall: 0.6538 - val_loss: 0.5648 - val_accuracy: 0.7216 - val_precision: 0.7353 - val_recall: 0.5814
# Epoch 100/100
# 10/10 [==============================] - 1s 114ms/step - loss: 0.5250 - accuracy: 0.7279 - precision: 0.6984 - recall: 0.6769 - val_loss: 0.5643 - val_accuracy: 0.7320 - val_precision: 0.6604 - val_recall: 0.8140

# %%
model.save('model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
plt.plot(fit_history.history['accuracy'])
plt.plot(fit_history.history['val_accuracy'])
plt.title('Model Olasılığı')
plt.ylabel('Olasılık')
plt.xlabel('Epoch')
plt.legend(['Eğitim', 'Doğrulama'], loc='upper left')
plt.show()

# %%
plt.plot(fit_history.history['loss'])
plt.plot(fit_history.history['val_loss'])
plt.title('Model Kaybı')
plt.ylabel('Kayıp (Loss)')
plt.xlabel('Epoch')
plt.legend(['Eğitim', 'Doğrulama'], loc='upper left')
plt.show()

# %%
loss, accuracy, precision, recall = model.evaluate(val_generator)
# Out:
# 7/7 [==============================] - 0s 35ms/step - loss: 0.5643 - accuracy: 0.7320 - precision: 0.6604 - recall: 0.8140

# %%
F1_Skoru = ((precision * recall) / (precision + recall)) * 2
F1_Skoru
# Out:
# 0.7291666700685802

# %%
y_true = val_generator.classes
pred = model.predict(val_generator)
pred = np.argmax(pred, axis=1)

cm = confusion_matrix(y_true, pred)
# Out:
# 7/7 [==============================] - 0s 33ms/step

# %%
cm
# Out:
# array([[54,  0],
#        [43,  0]])
